# %%
#importing libraries
import pandas as pd
import sys 
import urllib
from splinter import Browser
from bs4 import BeautifulSoup
import time
from selenium.webdriver import ChromeOptions

# %%
#options = {'chrome_options':['--disable-blink-features=AutomationControlled','--disable-setuid-sandbox']}

chrome_options = ChromeOptions()
#chrome_options.add_argument('--disable-blink-features=AutomationControlled')
#chrome_options.add_argument('start-maximized')
chrome_options.add_experimental_option("excludeSwitches", ["enable-automation"])
chrome_options.add_experimental_option('useAutomationExtension', False)
browser=Browser('chrome',options=chrome_options,headless=False)

# %%
#Launching automated browser & navigating to url of interest
#browser=Browser('chrome',headless=False)
url = 'https://www.leaguescup.com/schedule/#club=all&date=2023-07-30'
browser.visit(url)
#accepting policy
browser.find_by_xpath('//*[@id="onetrust-accept-btn-handler"]').click()

# %%
html = browser.html
#getting html script of the matches data and parsing it with beautiful soup
soup = BeautifulSoup(html,'html.parser')
#storing html with match information and link to more match details; found by searching for the class
matchesList=soup.body.find_all(class_='sc-dsHJmm ewkItn sm')

# %%
#creating empty lists to store scraped data
teams=[]
teamAbbs=[]
teamGoals=[]
homeOrAway=[]
teamPenalties=[]
teamPoints=[]
matchStadiums=[]
matchAttendance=[]
matchCity=[]
matchState=[]
matchReferee=[]
match_ast_referee1=[]
match_ast_referee2=[]
match_fourth_official=[]
match_VAR=[]
match_ast_VAR=[]
matchNumber=[]
opponent=[]
outcome=[]
penaltiesOutcome=[]
matchID=[]
homeTeams=[]
awayTeams=[]
roundCup=[]
teamPicUrls=[]
goalDiff=[]
Possession1=[]
Shots2=[]
Shots_on_Goal3=[]
Blocked_Shots4=[]
Total_Passes5=[]
Passing_Accuracy6=[]
Corners7=[]
Crosses8=[]
Offsides9=[]
Duels_Won10=[]
Won_Tackles11=[]
Saves12=[]
Clearances13=[]
Fouls14=[]
Yellow_Cards15=[]
Red_Cards16=[]
Overall17=[]
Attacking_Half18=[]
Final_Third19=[]
Crosses20=[]
Goals21=[]
On_Target22=[]
Off_Target23=[]
Blocked24=[]
Goals_Conceded25=[]
Shots_Against26=[]
Clean_Sheets27=[]
XG_Conceded28=[]
Interceptions29=[]
Goals30=[]
On_Target31=[]
Off_Target32=[]
Blocked33=[]
Overall34=[]
Attacking_Half35=[]
Final_Third36=[]
Crosses37=[]

#creating list of lists; for later collection of detailed game statistics
list_details = [Possession1,
Shots2,
Shots_on_Goal3,
Blocked_Shots4,
Total_Passes5,
Passing_Accuracy6,
Corners7,
Crosses8,
Offsides9,
Duels_Won10,
Won_Tackles11,
Saves12,
Clearances13,
Fouls14,
Yellow_Cards15,
Red_Cards16,
Overall17,
Attacking_Half18,
Final_Third19,
Crosses20,
Goals21,
On_Target22,
Off_Target23,
Blocked24,
Goals_Conceded25,
Shots_Against26,
Clean_Sheets27,
XG_Conceded28,
Interceptions29,
Goals30,
On_Target31,
Off_Target32,
Blocked33,
Overall34,
Attacking_Half35,
Final_Third36,
Crosses37]

# %%
#Scrapping for data needed

matchNum=0
#iterating through the html for each match and appending matchinformation into created lists
#website was dynamic so needed to include time functions and scrolling 
for match in matchesList:
    matchNum+=1
    if matchNum%5 == 0:
        browser.quit()
        time.sleep(5)
        browser=Browser('chrome',options=chrome_options,headless=False)
        browser.visit(url)
        time.sleep(5)
        browser.find_by_xpath('//*[@id="onetrust-accept-btn-handler"]').click()
    try:
        time.sleep(5)
        browser.execute_script("window.scrollTo(0, 0);")
        time.sleep(5)
        #navigating to more match details
        browser.links.find_by_href(match.find('a')['href']).click()
        time.sleep(5)
        browser.execute_script("window.scrollTo(0, 0);")
        
        #obtaining soup for location of stadium, referees, attendance
        html = browser.html
        matchDetailsSoup = BeautifulSoup(html,'html.parser')
        
        time.sleep(5)
        #navigating to get even more statistics of the matches
        #storing html in matchDetailsSoup2
        browser.find_by_text('Stats')[3].click()
        time.sleep(5)
        html = browser.html
        matchDetailsSoup2 = BeautifulSoup(html,'html.parser')
        #storing detailed stats for home and away teams in different lists
        detail_valuesHome = [i.text for i in matchDetailsSoup2.find_all(class_='mls-o-stat-chart__first-value')]
        detail_valuesAway = [i.text for i in matchDetailsSoup2.find_all(class_='mls-o-stat-chart__second-value')]

        
        
        #checking progress
        print('Match',matchNum,match.find(class_='sc-iveFHk jsryXz mls-c-status-stamp__status -post').text)
        print(match.find(class_='sc-eDWCr gclhmQ mls-c-match-tile --post').contents[0].find(class_='mls-c-club__shortname').text,match.find(class_='sc-eDWCr gclhmQ mls-c-match-tile --post').contents[2].find(class_='mls-c-club__shortname').text)
       
        #going back to our beautiful soups and storing more stats
        homeTeam = match.find(class_='sc-eDWCr gclhmQ mls-c-match-tile --post').contents[0].find(class_='mls-c-club__shortname').text
        homeTeamAbb = match.find(class_='sc-eDWCr gclhmQ mls-c-match-tile --post').contents[0].find(class_='mls-c-club__abbreviation').text
        homeTeamGoal = match.find(class_='sc-eDWCr gclhmQ mls-c-match-tile --post').contents[1].find_all(class_='mls-c-scorebug__score')[0].text
        homeTeamPicUrlUnprepared = match.find_all(class_='mls-c-club__picture')[0]['src']
        homeTeamPicUrl=homeTeamPicUrlUnprepared.split('upload')[0]+'upload/w_700,h_700/assets'+homeTeamPicUrlUnprepared.split('/assets')[1]
        
        awayTeam = match.find(class_='sc-eDWCr gclhmQ mls-c-match-tile --post').contents[2].find(class_='mls-c-club__shortname').text
        awayTeamAbb = match.find(class_='sc-eDWCr gclhmQ mls-c-match-tile --post').contents[2].find(class_='mls-c-club__abbreviation').text
        awayTeamGoal = match.find(class_='sc-eDWCr gclhmQ mls-c-match-tile --post').contents[1].find_all(class_='mls-c-scorebug__score')[1].text
        awayTeamPicUrlUnprepared = match.find_all(class_='mls-c-club__picture')[1]['src']
        awayTeamPicUrl = awayTeamPicUrlUnprepared.split('upload')[0]+'upload/w_700,h_700/assets'+awayTeamPicUrlUnprepared.split('/assets')[1]
        
        matchStadium = match.find(class_='sc-kgTSHT fROhf').text
        
        #obtaining location of stadium, referees, attendance
        city = matchDetailsSoup.find_all(class_='mls-o-match-facts__value')[1].text.split(',')[0]
        state = matchDetailsSoup.find_all(class_='mls-o-match-facts__value')[1].text.split(',')[1]
        referee = matchDetailsSoup.find_all(class_='mls-o-match-facts__value')[2].text
        ast_Referee_1= matchDetailsSoup.find_all(class_='mls-o-match-facts__value')[3].text
        ast_Referee_2= matchDetailsSoup.find_all(class_='mls-o-match-facts__value')[4].text
        fourth_official = matchDetailsSoup.find_all(class_='mls-o-match-facts__value')[5].text
        var = matchDetailsSoup.find_all(class_='mls-o-match-facts__value')[6].text
        ast_var = matchDetailsSoup.find_all(class_='mls-o-match-facts__value')[7].text
        attendance = matchDetailsSoup.find_all(class_='mls-o-match-facts__value')[-1].text
        
        #calculating the round
        if matchNum <= 45:
            roundCup.append('Qualifying')
        elif matchNum > 45 and matchNum <= 77:
            roundCup.append('Round of 32')
        elif matchNum > 77 and matchNum <= 93:
            roundCup.append('Round of 16')
        elif matchNum > 93 and matchNum <= 97:
            roundCup.append('Quarter Finals')
        elif matchNum > 97 and matchNum <= 99:
            roundCup.append('Semifinals')
        else:
            roundCup.append('Final')
        
        try:
        #penalties results are not easily structured so additional logic is needed
            #getting the penalty results example format: (5,4)
            penalty = (match.find(class_='sc-gScZFl iZdhyg').text.split(':')[0][-2:].strip(),match.find(class_='sc-gScZFl iZdhyg').text.split(':')[1][:2])
            #extracting team who wins penalties example format: 'ORL wins 5:4 on PKs'
            if match.find(class_='sc-gScZFl iZdhyg').text.split(' ')[0]== match.find(class_='sc-eDWCr gclhmQ mls-c-match-tile --post').contents[0].find(class_='mls-c-club__abbreviation').text:
                print('Home Team wins penalties')
                homeTeamPenalty = max(penalty)
                awayTeamPenalty = min(penalty)
                
            else:
                print('Away Team Wins penalties')
                homeTeamPenalty = min(penalty)
                awayTeamPenalty = max(penalty)
                
        except:
            print('No penalties played')
            homeTeamPenalty = 0
            awayTeamPenalty = 0
            
        #calculating team points, teams get addtional point for winning in the penalty kicks    
        homeTeamPoint=0
        awayTeamPoint=0
        
        if homeTeamGoal>awayTeamGoal:
            homeTeamPoint+=3
            homeTeamOutcome='W'
            awayTeamOutcome='L'
            homePOutcome='NA'
            awayPOutcome='NA'
        elif homeTeamGoal<awayTeamGoal:
            awayTeamPoint+=3
            homeTeamOutcome='L'
            awayTeamOutcome='W'
            homePOutcome='NA'
            awayPOutcome='NA'    
        elif homeTeamGoal == awayTeamGoal and homeTeamPenalty>awayTeamPenalty:
            homeTeamPoint+=2
            awayTeamPoint+=1
            homeTeamOutcome='T'
            awayTeamOutcome='T'
            homePOutcome='W'
            awayPOutcome='L'
        elif homeTeamGoal == awayTeamGoal and homeTeamPenalty<awayTeamPenalty:
            homeTeamPoint+=1
            awayTeamPoint+=2
            homeTeamOutcome='T'
            awayTeamOutcome='T'
            homePOutcome='L'
            awayPOutcome='W'
        
        #appending all info into created lists
        matchID.append(matchNum)
        homeTeams.append(homeTeam)
        awayTeams.append(awayTeam)
        
        teamPenalties.append(homeTeamPenalty)        
        teamGoals.append(homeTeamGoal)    
        teamAbbs.append(homeTeamAbb)    
        teams.append(homeTeam)    
        teamPoints.append(homeTeamPoint)
        matchStadiums.append(matchStadium)
        homeOrAway.append('Home')
        opponent.append(awayTeam)
        matchNumber.append(matchNum)
        outcome.append(homeTeamOutcome)
        penaltiesOutcome.append(homePOutcome)
        teamPicUrls.append(homeTeamPicUrl)
        goalDiff.append(abs(int(homeTeamGoal)-int(awayTeamGoal)))
        
        matchAttendance.append(attendance)
        matchCity.append(city)
        matchState.append(state)
        matchReferee.append(referee)
        match_ast_referee1.append(ast_Referee_1)
        match_ast_referee2.append(ast_Referee_2)
        match_fourth_official.append(fourth_official)
        match_VAR.append(var)
        match_ast_VAR.append(ast_var)
        
        
        #away match info
        teams.append(awayTeam)
        teamAbbs.append(awayTeamAbb)
        teamGoals.append(awayTeamGoal)
        teamPenalties.append(awayTeamPenalty)
        teamPoints.append(awayTeamPoint)
        homeOrAway.append('Away')
        opponent.append(homeTeam)
        matchStadiums.append(matchStadium)
        matchNumber.append(matchNum)
        outcome.append(awayTeamOutcome)
        penaltiesOutcome.append(awayPOutcome)
        teamPicUrls.append(awayTeamPicUrl)
        goalDiff.append(abs(int(homeTeamGoal)-int(awayTeamGoal)))
        
        matchAttendance.append(attendance)
        matchCity.append(city)
        matchState.append(state)
        matchReferee.append(referee)
        match_ast_referee1.append(ast_Referee_1)
        match_ast_referee2.append(ast_Referee_2)
        match_fourth_official.append(fourth_official)
        match_VAR.append(var)
        match_ast_VAR.append(ast_var)
        
        #fancy way of appending detailed stats 
        for x,y,z in zip(list_details,detail_valuesHome,detail_valuesAway):
            x.append(y)
            x.append(z)
        
        
    #if match has not been played then error will be thrown, error is caught and "match has not been played" is outputed     
    except:
        print('Match', matchNum,'has not been played')
    #adding sleep time and navigating back to scheadule
    time.sleep(2)
    browser.visit('https://www.leaguescup.com/schedule/#club=all&date=2023-07-30')
browser.quit()

# %%
#### creating our dataframes
matchDetailsDic = {'Match_id': matchNumber,
        'Team':teams,
        'Home_Away':homeOrAway,
        'Outcome':outcome,
       'Goals':teamGoals,
        'Opponent':opponent,
       'Team_penalties':teamPenalties,
        'Penalties_outcome':penaltiesOutcome,
       'Team_points': teamPoints,
        'Match_Stadium':matchStadiums,
        'Team_pic_urls': teamPicUrls,
        'Goal_Difference':goalDiff,
        'matchAttendance': matchAttendance,
        'matchCity': matchCity,
        'matchState':matchState,
        'matchReferee':matchReferee,
        'match_ast_referee1':match_ast_referee1,
        'match_ast_referee2':match_ast_referee2,
        'match_fourth_official': match_fourth_official,
        'match_VAR':match_VAR,
        'match_ast_VAR':match_ast_VAR,
        'Possession1':Possession1,
        'Shots2':Shots2,
        'Shots_on_Goal3':Shots_on_Goal3,
        'Blocked_Shots4':Blocked_Shots4,
        'Total_Passes5':Total_Passes5,
        'Passing_Accuracy6':Passing_Accuracy6,
        'Corners7':Corners7,
        'Crosses8':Crosses8,
        'Offsides9':Offsides9,
        'Duels_Won10':Duels_Won10,
        'Won_Tackles11':Won_Tackles11,
        'Saves12':Saves12,
        'Clearances13':Clearances13,
        'Fouls14':Fouls14,
        'Yellow_Cards15':Yellow_Cards15,
        'Red_Cards16':Red_Cards16,
        'Overall17':Overall17,
        'Attacking_Half18':Attacking_Half18,
        'Final_Third19':Final_Third19,
        'Crosses20':Crosses20,
        'Goals21':Goals21,
        'On_Target22':On_Target22,
        'Off_Target23':Off_Target23,
        'Blocked24':Blocked24,
        'Goals_Conceded25':Goals_Conceded25,
        'Shots_Against26':Shots_Against26,
        'Clean_Sheets27':Clean_Sheets27,
        'XG_Conceded28':XG_Conceded28,
        'Interceptions29':Interceptions29,
        'Goals30':Goals30,
        'On_Target31':On_Target31,
        'Off_Target32':Off_Target32,
        'Blocked33':Blocked33,
        'Overall34':Overall34,
        'Attacking_Half35':Attacking_Half35,
        'Final_Third36':Final_Third36,
        'Crosses37':Crosses37
       }
matchDic = {'Match_ID':matchID,
        'Home_Team':homeTeams,
        'Away_Team':awayTeams,
        'Round':roundCup}
matchDetailsDF = pd.DataFrame(matchDetailsDic)
matches = pd.DataFrame(matchDic)

# %%
pd.set_option('display.max_rows', None)
matches=matches.drop(columns=['League_vs_League'])

matches

# %%
matchDetailsDF=matchDetailsDF.drop(columns=['League'])
matchDetailsDF

# %%
#saftey
#matchDetailsDic = {'Match_id': matchNumber,
        'Team':teams,
        'Home_Away':homeOrAway,
        'Outcome':outcome,
       'Goals':teamGoals,
        'Opponent':opponent,
       'Team_penalties':teamPenalties,
        'Penalties_outcome':penaltiesOutcome,
       'Team_points': teamPoints,
        'Match_Stadium':matchStadiums,
        'Team_pic_urls': teamPicUrls,
        'Goal_Difference':goalDiff,
        'matchAttendance': matchAttendance,
        'matchCity': matchCity,
        'matchState':matchState,
        'matchReferee':matchReferee,
        'match_ast_referee1':match_ast_referee1,
        'match_ast_referee2':match_ast_referee2,
        'match_fourth_official': match_fourth_official,
        'match_VAR':match_VAR,
        'match_ast_VAR':match_ast_VAR,
        'Possession1':Possession1[:-2],
        'Shots2':Shots2[:-2],
        'Shots_on_Goal3':Shots_on_Goal3[:-2],
        'Blocked_Shots4':Blocked_Shots4[:-2],
        'Total_Passes5':Total_Passes5[:-2],
        'Passing_Accuracy6':Passing_Accuracy6[:-2],
        'Corners7':Corners7[:-2],
        'Crosses8':Crosses8[:-2],
        'Offsides9':Offsides9[:-2],
        'Duels_Won10':Duels_Won10[:-2],
        'Won_Tackles11':Won_Tackles11[:-2],
        'Saves12':Saves12[:-2],
        'Clearances13':Clearances13[:-2],
        'Fouls14':Fouls14[:-2],
        'Yellow_Cards15':Yellow_Cards15[:-2],
        'Red_Cards16':Red_Cards16[:-2],
        'Overall17':Overall17[:-2],
        'Attacking_Half18':Attacking_Half18[:-2],
        'Final_Third19':Final_Third19[:-2],
        'Crosses20':Crosses20[:-2],
        'Goals21':Goals21[:-2],
        'On_Target22':On_Target22[:-2],
        'Off_Target23':Off_Target23[:-2],
        'Blocked24':Blocked24[:-2],
        'Goals_Conceded25':Goals_Conceded25[:-2],
        'Shots_Against26':Shots_Against26[:-2],
        'Clean_Sheets27':Clean_Sheets27[:-2],
        'XG_Conceded28':XG_Conceded28[:-2],
        'Interceptions29':Interceptions29[:-2],
        'Goals30':Goals30[:-2],
        'On_Target31':On_Target31[:-2],
        'Off_Target32':Off_Target32[:-2],
        'Blocked33':Blocked33[:-2],
        'Overall34':Overall34[:-2],
        'Attacking_Half35':Attacking_Half35[:-2],
        'Final_Third36':Final_Third36[:-2],
        'Crosses37':Crosses37[:-2]
       }

# %%
teams = matchDetailsDF[['Team','Team_pic_urls']].drop_duplicates().reset_index(drop=True)
league = pd.DataFrame({'League':['Liga MX','MLS','MLS','MLS','MLS','Liga MX','MLS','MLS','Liga MX','MLS','MLS','Liga MX','MLS','MLS','MLS','Liga MX','MLS','MLS','MLS','MLS','MLS','Liga MX','MLS','MLS','MLS','MLS','Liga MX','MLS','MLS','MLS','MLS','Liga MX','Liga MX','Liga MX','MLS','MLS','Liga MX','Liga MX','MLS', 'Liga MX', 'MLS', 'Liga MX', 'Liga MX', 'Liga MX', 'Liga MX', 'Liga MX', 'MLS']})
................................['Liga MX','MLS','MLS','MLS','MLS','Liga MX','MLS','MLS','Liga MX','MLS','MLS','Liga MX','MLS','MLS','MLS','Liga MX','MLS','MLS','MLS','MLS','MLS','Liga MX','MLS','MLS','MLS','MLS','Liga MX','MLS','MLS','MLS','MLS','Liga MX','Liga MX','Liga MX','MLS','MLS','Liga MX','Liga MX','MLS', 'Liga MX', 'MLS', 'Liga MX', 'Liga MX', 'Liga MX', 'Liga MX', 'Liga MX', 'MLS']})

# %%
teams

# %%
#associating teams with a league, manual since data was not available in the website
#creating league vs league attribute
league = pd.DataFrame({'League':['Liga MX','MLS','MLS','MLS','MLS','Liga MX','MLS','MLS','Liga MX','MLS','MLS','Liga MX','MLS','MLS','MLS','Liga MX','MLS','MLS','MLS','MLS','MLS','Liga MX','MLS','MLS','MLS','MLS','Liga MX','MLS','MLS','MLS','MLS','Liga MX','Liga MX','Liga MX','MLS','MLS','Liga MX','Liga MX','Liga MX', 'MLS', 'Liga MX', 'MLS', 'Liga MX', 'Liga MX', 'Liga MX', 'Liga MX', 'MLS']})

teams = matchDetailsDF[['Team','Team_pic_urls']].drop_duplicates().reset_index(drop=True)
teamsDF = pd.concat([teams,league],axis=1)
teamsDF.to_csv('Teams.csv',index=False)

matchDetailsDF = pd.merge(matchDetailsDF,teamsDF[['Team','League']],how='left',left_on='Team',right_on='Team')
matchDetailsDF = matchDetailsDF[['Match_id', 'Team', 'Home_Away', 'Outcome', 'Goals', 'Opponent',
       'Team_penalties', 'Penalties_outcome', 'Team_points', 'Match_Stadium',
       'Team_pic_urls','League','Goal_Difference','matchAttendance','matchCity','matchState','matchReferee',
        'match_ast_referee1','match_ast_referee2','match_fourth_official','match_VAR','match_ast_VAR','Possession1',
'Shots2','Shots_on_Goal3','Blocked_Shots4','Total_Passes5','Passing_Accuracy6','Corners7','Crosses8','Offsides9',
'Duels_Won10','Won_Tackles11','Saves12','Clearances13','Fouls14','Yellow_Cards15','Red_Cards16','Overall17','Attacking_Half18',
'Final_Third19','Crosses20','Goals21','On_Target22','Off_Target23','Blocked24','Goals_Conceded25','Shots_Against26',
'Clean_Sheets27','XG_Conceded28','Interceptions29','Goals30','On_Target31','Off_Target32','Blocked33','Overall34',
'Attacking_Half35','Final_Third36','Crosses37']]
matchDetailsDF.to_csv('MatchDetails.csv',index=False)

tempTeam=teamsDF.set_index('Team')
LvL = []
for home,away in zip(matches['Home_Team'],matches['Away_Team']):
    if tempTeam.loc[home,'League'] !=tempTeam.loc[away,'League']:
        LvL.append('League vs League')
    else:
        LvL.append('No Rivalry')
lvlDF = pd.DataFrame({'League_vs_League':LvL})
        
matches=pd.merge(matches,lvlDF,left_index=True,right_index=True)
matches.to_csv('Matches.csv',index=False)

# %%
pd.set_option('display.max_rows', None)
teamsDF

# %%
#creating matrix to help make tableau visualization
mID= [] #matchID
ts=[] # team socring
gs=[] # goals scored

#essentially: for every game for every team a new line will be created for every goal they score, see output for further clarity
for matchID,team,goals in zip(matchDetailsDF['Match_id'],matchDetailsDF['Team'],matchDetailsDF['Goals']):
    for g in range(int(goals)):
        mID.append(matchID)
        ts.append(team)
        gs.append(1)
goalsTrackerDF=pd.DataFrame({'Match_id':mID,'Team':ts,'goal_tracker':gs})    
goalsTrackerDF.to_csv('goalsTracker.csv',index=False)

# %%
goalsTrackerDF
